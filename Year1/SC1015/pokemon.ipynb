# %% [markdown]
# # The Pokemon Dataset Exploration

# %% [markdown]
# ### Import the essential libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ### Import pokemonData.csv

# %%
pokemon_data = pd.read_csv('D:\Coding\Ry3nWorkspace\SC1015_DataScienceAndAI\Lab1\pokemonData.csv')
pokemon_data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
hp = pd.DataFrame(pokemon_data['HP'])
print("Data type : ", type(hp))
print("Data dims : ", hp.size)
hp.head()
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  800
#    HP
# 0  45
# 1  60
# 2  80
# 3  80
# 4  39

# %%
sb.histplot(data = hp)
# Out:
# <AxesSubplot:ylabel='Count'>
